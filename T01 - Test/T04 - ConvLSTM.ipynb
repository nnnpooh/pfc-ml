# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle

# %%
# Load data (deserialize)
with open('filename.pickle', 'rb') as handle:
    data_dict = pickle.load(handle)

data = data_dict["data"]
nCol = data_dict["n"]
nRow = 1
nChannel = 1
tFinal = data_dict["tf"]
dx = data_dict["dx"]
L = data_dict["L"]

# %%
nSeq = 10

# %%
def split_sequence(data, nSeq):

    X, y = list(), list()
    nRow = data.shape[0]
    for i in range(nRow):
		# find the end of this pattern
        end_ix = i + nSeq
		# check if we are beyond the sequence
        if end_ix > nRow - 1:
            break
		# gather input and output parts of the pattern
        seq_x, seq_y = data[i:end_ix, :], data[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X_, y = split_sequence(data, nSeq)
print(X_.shape)
print(y.shape)
# Out:
# (91, 10, 32)
# (91, 32)

# %%
X_.shape
# Out:
# (91, 10, 32)

# %%
X = X_.reshape(X_.shape[0], nSeq, nRow, nCol, nChannel)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Input, SimpleRNN, GRU, Conv1D, MaxPooling1D, Flatten, ConvLSTM2D

def createModel(type):
    inputLayer = Input(shape=(nSeq, nRow, nCol, nChannel))

    if (type == 'ConvLSTM'):
        layer = ConvLSTM2D(filters=64, kernel_size=(1,3), activation='relu')(inputLayer)
        layer = Flatten()(layer)
    
    outputLayer = Dense(nCol)(layer)
    model = Model(inputs=inputLayer, outputs=outputLayer, name=type)

    return model

# %%
# Model building
tf.keras.backend.clear_session()
tf.random.set_seed(1)
# For somereason if I don't include this, I cannot execute this cell twice for LSTM and GRU
from tensorflow.keras.layers import LSTM, GRU

ConvLSTM = createModel('ConvLSTM')

ConvLSTM.summary()
# Out:
# Model: "ConvLSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 1, 32, 1)]    0
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 1, 30, 64)         50176
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                61472
# =================================================================
# Total params: 111,648
# Trainable params: 111,648
# Non-trainable params: 0
# _________________________________________________________________
# 2022-04-30 06:53:45.320219: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-30 06:53:45.320934: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-30 06:53:45.324104: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
from tensorflow.keras.callbacks import EarlyStopping

def runModel(model, X, y, **kwargs):

    learning_rate = 0.001
    if 'learning_rate' in kwargs:
        learning_rate = kwargs['learning_rate']

    patience = 10
    if 'patience' in kwargs:
        patience = kwargs['patience']

    epochs=200
    if 'epochs' in kwargs:
        epochs = kwargs['epochs']

    optimizer = tf.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse')

    earlyStoppingCallback = EarlyStopping(monitor='loss', patience=patience, min_delta=0)

    history = model.fit(X, y, epochs=epochs, verbose=1, callbacks=[earlyStoppingCallback ])

    hist = history.history
    x_arr = np.arange(len(hist['loss'])) + 1
    fig = plt.figure(figsize=(12, 4))
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
    ax.set_xlabel('Epoch', size=15)
    ax.set_ylabel('Loss', size=15)
    ax.legend(fontsize=15)
    plt.show()

# %%
runModel(ConvLSTM, X, y, learning_rate=0.001, epochs=2000, patience=30)
# Out:
# 2022-04-30 06:53:45.586740: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-04-30 06:53:45.609075: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3593215000 Hz
# Epoch 1/2000
# 3/3 [==============================] - 2s 134ms/step - loss: 0.0577
# Epoch 2/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.0404
# Epoch 3/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0172
# Epoch 4/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 0.0110
# Epoch 5/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0039
# Epoch 6/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.0043
# Epoch 7/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0048
# Epoch 8/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0035
# Epoch 9/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0028
# Epoch 10/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 0.0025
# Epoch 11/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0019
# Epoch 12/2000
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0017
# Epoch 13/2000
# 3/3 [==============================] - 1s 220ms/step - loss: 0.0014
# Epoch 14/2000
# 3/3 [==============================] - 1s 461ms/step - loss: 0.0011
# Epoch 15/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 9.5490e-04
# Epoch 16/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 6.4947e-04
# Epoch 17/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 4.9331e-04
# Epoch 18/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 3.9194e-04
# Epoch 19/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.3754e-04
# Epoch 20/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 1.7806e-04
# Epoch 21/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 1.1304e-04
# Epoch 22/2000
# 3/3 [==============================] - 1s 250ms/step - loss: 8.9866e-05
# Epoch 23/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 7.1240e-05
# Epoch 24/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 6.1170e-05
# Epoch 25/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 6.6747e-05
# Epoch 26/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 6.0668e-05
# Epoch 27/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 4.9117e-05
# Epoch 28/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 3.9659e-05
# Epoch 29/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 3.3501e-05
# Epoch 30/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 2.6984e-05
# Epoch 31/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 2.7949e-05
# Epoch 32/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 2.4736e-05
# Epoch 33/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 2.5264e-05
# Epoch 34/2000
# 3/3 [==============================] - 1s 242ms/step - loss: 2.2255e-05
# Epoch 35/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 1.7959e-05
# Epoch 36/2000
# 3/3 [==============================] - 1s 172ms/step - loss: 1.5492e-05
# Epoch 37/2000
# 3/3 [==============================] - 1s 218ms/step - loss: 1.4837e-05
# Epoch 38/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 1.2476e-05
# Epoch 39/2000
# 3/3 [==============================] - 1s 163ms/step - loss: 1.1927e-05
# Epoch 40/2000
# 3/3 [==============================] - 1s 258ms/step - loss: 9.9467e-06
# Epoch 41/2000
# 3/3 [==============================] - 1s 232ms/step - loss: 7.9916e-06
# Epoch 42/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 6.7459e-06
# Epoch 43/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 7.0317e-06
# Epoch 44/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 5.6363e-06
# Epoch 45/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 4.9165e-06
# Epoch 46/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 3.8379e-06
# Epoch 47/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 3.9673e-06
# Epoch 48/2000
# 3/3 [==============================] - 0s 176ms/step - loss: 3.1275e-06
# Epoch 49/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 3.3080e-06
# Epoch 50/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 2.9400e-06
# Epoch 51/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 2.4066e-06
# Epoch 52/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 2.5474e-06
# Epoch 53/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 2.2334e-06
# Epoch 54/2000
# 3/3 [==============================] - 1s 216ms/step - loss: 2.1689e-06
# Epoch 55/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 1.9592e-06
# Epoch 56/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 1.8476e-06
# Epoch 57/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.7039e-06
# Epoch 58/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 1.6242e-06
# Epoch 59/2000
# 3/3 [==============================] - 1s 250ms/step - loss: 1.5819e-06
# Epoch 60/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 1.5404e-06
# Epoch 61/2000
# 3/3 [==============================] - 0s 168ms/step - loss: 1.3502e-06
# Epoch 62/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.2682e-06
# Epoch 63/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.3183e-06
# Epoch 64/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.2767e-06
# Epoch 65/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 1.2538e-06
# Epoch 66/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.0991e-06
# Epoch 67/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 1.0076e-06
# Epoch 68/2000
# 3/3 [==============================] - 1s 101ms/step - loss: 1.1455e-06
# Epoch 69/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 9.8283e-07
# Epoch 70/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 9.9975e-07
# Epoch 71/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 9.5854e-07
# Epoch 72/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 9.8202e-07
# Epoch 73/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 9.8586e-07
# Epoch 74/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 8.4148e-07
# Epoch 75/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 8.5934e-07
# Epoch 76/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 7.4341e-07
# Epoch 77/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 8.1473e-07
# Epoch 78/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 7.6817e-07
# Epoch 79/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 6.4447e-07
# Epoch 80/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 6.5387e-07
# Epoch 81/2000
# 3/3 [==============================] - 1s 168ms/step - loss: 6.7875e-07
# Epoch 82/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 5.6695e-07
# Epoch 83/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 6.6362e-07
# Epoch 84/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 6.1734e-07
# Epoch 85/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 5.8443e-07
# Epoch 86/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 5.3845e-07
# Epoch 87/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 5.4586e-07
# Epoch 88/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 5.2141e-07
# Epoch 89/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 5.0580e-07
# Epoch 90/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 5.1657e-07
# Epoch 91/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 4.9812e-07
# Epoch 92/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 4.5598e-07
# Epoch 93/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 4.2514e-07
# Epoch 94/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 4.6838e-07
# Epoch 95/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 4.4975e-07
# Epoch 96/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 3.8344e-07
# Epoch 97/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 4.1234e-07
# Epoch 98/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 4.0556e-07
# Epoch 99/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 3.4120e-07
# Epoch 100/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 3.6664e-07
# Epoch 101/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 3.5350e-07
# Epoch 102/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 3.2406e-07
# Epoch 103/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 3.5809e-07
# Epoch 104/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 3.2517e-07
# Epoch 105/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 3.4452e-07
# Epoch 106/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 3.2765e-07
# Epoch 107/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.2842e-07
# Epoch 108/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 2.6951e-07
# Epoch 109/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 3.1102e-07
# Epoch 110/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 2.8819e-07
# Epoch 111/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 2.7223e-07
# Epoch 112/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 2.5941e-07
# Epoch 113/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 2.7698e-07
# Epoch 114/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 2.3894e-07
# Epoch 115/2000
# 3/3 [==============================] - 1s 217ms/step - loss: 2.6718e-07
# Epoch 116/2000
# 3/3 [==============================] - 1s 273ms/step - loss: 2.6897e-07
# Epoch 117/2000
# 3/3 [==============================] - 1s 228ms/step - loss: 2.2281e-07
# Epoch 118/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 2.4016e-07
# Epoch 119/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 2.1509e-07
# Epoch 120/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 2.0086e-07
# Epoch 121/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 2.1224e-07
# Epoch 122/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 2.0979e-07
# Epoch 123/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 2.0135e-07
# Epoch 124/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 2.2292e-07
# Epoch 125/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 2.0416e-07
# Epoch 126/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 1.9278e-07
# Epoch 127/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.9934e-07
# Epoch 128/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 2.0368e-07
# Epoch 129/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.7766e-07
# Epoch 130/2000
# 3/3 [==============================] - 0s 190ms/step - loss: 1.8507e-07
# Epoch 131/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 1.8590e-07
# Epoch 132/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 1.8759e-07
# Epoch 133/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 1.6966e-07
# Epoch 134/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.7566e-07
# Epoch 135/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.7595e-07
# Epoch 136/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.6367e-07
# Epoch 137/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.8670e-07
# Epoch 138/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 1.6914e-07
# Epoch 139/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.6303e-07
# Epoch 140/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 1.5029e-07
# Epoch 141/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 1.8340e-07
# Epoch 142/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.5538e-07
# Epoch 143/2000
# 3/3 [==============================] - 1s 130ms/step - loss: 1.5006e-07
# Epoch 144/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 1.5473e-07
# Epoch 145/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 1.4898e-07
# Epoch 146/2000
# 3/3 [==============================] - 1s 157ms/step - loss: 1.4550e-07
# Epoch 147/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 1.3566e-07
# Epoch 148/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 1.3771e-07
# Epoch 149/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 1.5063e-07
# Epoch 150/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 1.1210e-07
# Epoch 151/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 1.2503e-07
# Epoch 152/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.3250e-07
# Epoch 153/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.3790e-07
# Epoch 154/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.3092e-07
# Epoch 155/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.3404e-07
# Epoch 156/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 1.1394e-07
# Epoch 157/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.2060e-07
# Epoch 158/2000
# 3/3 [==============================] - 0s 169ms/step - loss: 1.0891e-07
# Epoch 159/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.1482e-07
# Epoch 160/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0362e-07
# Epoch 161/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0755e-07
# Epoch 162/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.2144e-07
# Epoch 163/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0627e-07
# Epoch 164/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 9.6067e-08
# Epoch 165/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.6076e-08
# Epoch 166/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 9.6505e-08
# Epoch 167/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0757e-07
# Epoch 168/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 9.8423e-08
# Epoch 169/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 1.0261e-07
# Epoch 170/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 9.2892e-08
# Epoch 171/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 8.7083e-08
# Epoch 172/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 9.1436e-08
# Epoch 173/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0369e-07
# Epoch 174/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 9.2072e-08
# Epoch 175/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 9.0804e-08
# Epoch 176/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 8.0137e-08
# Epoch 177/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 9.1807e-08
# Epoch 178/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 8.7190e-08
# Epoch 179/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 7.7615e-08
# Epoch 180/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 7.6704e-08
# Epoch 181/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 8.3219e-08
# Epoch 182/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 7.9849e-08
# Epoch 183/2000
# 3/3 [==============================] - 0s 180ms/step - loss: 6.8156e-08
# Epoch 184/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 7.7714e-08
# Epoch 185/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 7.6382e-08
# Epoch 186/2000
# 3/3 [==============================] - 1s 266ms/step - loss: 7.1988e-08
# Epoch 187/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 7.6690e-08
# Epoch 188/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 7.0569e-08
# Epoch 189/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 7.4403e-08
# Epoch 190/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 7.2195e-08
# Epoch 191/2000
# 3/3 [==============================] - 0s 174ms/step - loss: 7.6487e-08
# Epoch 192/2000
# 3/3 [==============================] - 1s 216ms/step - loss: 7.0240e-08
# Epoch 193/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 6.9221e-08
# Epoch 194/2000
# 3/3 [==============================] - 1s 226ms/step - loss: 6.7602e-08
# Epoch 195/2000
# 3/3 [==============================] - 1s 170ms/step - loss: 6.9606e-08
# Epoch 196/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 7.0072e-08
# Epoch 197/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 7.0396e-08
# Epoch 198/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 6.4764e-08
# Epoch 199/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 6.8119e-08
# Epoch 200/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 6.4470e-08
# Epoch 201/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 7.1766e-08
# Epoch 202/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 6.0935e-08
# Epoch 203/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 6.4164e-08
# Epoch 204/2000
# 3/3 [==============================] - 1s 224ms/step - loss: 5.7845e-08
# Epoch 205/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 5.8969e-08
# Epoch 206/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 6.5771e-08
# Epoch 207/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 5.6231e-08
# Epoch 208/2000
# 3/3 [==============================] - 1s 218ms/step - loss: 6.4757e-08
# Epoch 209/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 5.9869e-08
# Epoch 210/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.0556e-08
# Epoch 211/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 5.6756e-08
# Epoch 212/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 6.4265e-08
# Epoch 213/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 5.1263e-08
# Epoch 214/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 6.3536e-08
# Epoch 215/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 6.1352e-08
# Epoch 216/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 6.3803e-08
# Epoch 217/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 5.6228e-08
# Epoch 218/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 5.6820e-08
# Epoch 219/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 5.1921e-08
# Epoch 220/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 5.6035e-08
# Epoch 221/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 5.6559e-08
# Epoch 222/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 5.4727e-08
# Epoch 223/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 5.7251e-08
# Epoch 224/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 4.7980e-08
# Epoch 225/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 4.6443e-08
# Epoch 226/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 5.1205e-08
# Epoch 227/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 4.6490e-08
# Epoch 228/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 5.3709e-08
# Epoch 229/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 5.5203e-08
# Epoch 230/2000
# 3/3 [==============================] - 1s 128ms/step - loss: 4.6709e-08
# Epoch 231/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 4.8632e-08
# Epoch 232/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 5.0634e-08
# Epoch 233/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 4.9339e-08
# Epoch 234/2000
# 3/3 [==============================] - 1s 162ms/step - loss: 5.1488e-08
# Epoch 235/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 4.7658e-08
# Epoch 236/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 4.8730e-08
# Epoch 237/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.4844e-08
# Epoch 238/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 4.3303e-08
# Epoch 239/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 4.8175e-08
# Epoch 240/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 5.0036e-08
# Epoch 241/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 4.1888e-08
# Epoch 242/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 4.1956e-08
# Epoch 243/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 4.5560e-08
# Epoch 244/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 4.6778e-08
# Epoch 245/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 4.0571e-08
# Epoch 246/2000
# 3/3 [==============================] - 1s 372ms/step - loss: 3.9343e-08
# Epoch 247/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 4.5044e-08
# Epoch 248/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 4.4240e-08
# Epoch 249/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 4.3339e-08
# Epoch 250/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 4.4668e-08
# Epoch 251/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 4.2134e-08
# Epoch 252/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 4.4476e-08
# Epoch 253/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 4.1017e-08
# Epoch 254/2000
# 3/3 [==============================] - 1s 150ms/step - loss: 4.2892e-08
# Epoch 255/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 4.2778e-08
# Epoch 256/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 3.7456e-08
# Epoch 257/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 4.6260e-08
# Epoch 258/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 4.9223e-08
# Epoch 259/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 4.4129e-08
# Epoch 260/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 4.1569e-08
# Epoch 261/2000
# 3/3 [==============================] - 1s 263ms/step - loss: 4.3269e-08
# Epoch 262/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 4.0703e-08
# Epoch 263/2000
# 3/3 [==============================] - 1s 150ms/step - loss: 4.3193e-08
# Epoch 264/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 4.5113e-08
# Epoch 265/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 4.8774e-08
# Epoch 266/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 5.3084e-08
# Epoch 267/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 5.3658e-08
# Epoch 268/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 5.3839e-08
# Epoch 269/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.4842e-08
# Epoch 270/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 4.1124e-08
# Epoch 271/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 4.7390e-08
# Epoch 272/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 4.1531e-08
# Epoch 273/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.3457e-08
# Epoch 274/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 3.2444e-08
# Epoch 275/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 3.0804e-08
# Epoch 276/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 3.3687e-08
# Epoch 277/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 3.3074e-08
# Epoch 278/2000
# 3/3 [==============================] - 1s 223ms/step - loss: 3.1494e-08
# Epoch 279/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 3.3817e-08
# Epoch 280/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 3.5852e-08
# Epoch 281/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 3.2676e-08
# Epoch 282/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.7870e-08
# Epoch 283/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 3.7574e-08
# Epoch 284/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 3.7586e-08
# Epoch 285/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 4.0952e-08
# Epoch 286/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 4.0522e-08
# Epoch 287/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 4.4982e-08
# Epoch 288/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 4.6009e-08
# Epoch 289/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 4.2176e-08
# Epoch 290/2000
# 3/3 [==============================] - 1s 167ms/step - loss: 3.7566e-08
# Epoch 291/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 4.0123e-08
# Epoch 292/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.6428e-08
# Epoch 293/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 3.7433e-08
# Epoch 294/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 3.3374e-08
# Epoch 295/2000
# 3/3 [==============================] - 1s 376ms/step - loss: 3.5355e-08
# Epoch 296/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 3.5821e-08
# Epoch 297/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 3.1464e-08
# Epoch 298/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 2.9568e-08
# Epoch 299/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 3.0519e-08
# Epoch 300/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 3.3298e-08
# Epoch 301/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 3.0907e-08
# Epoch 302/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 3.5098e-08
# Epoch 303/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 2.9456e-08
# Epoch 304/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 3.2682e-08
# Epoch 305/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 3.6653e-08
# Epoch 306/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.9970e-08
# Epoch 307/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.0331e-08
# Epoch 308/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 3.4728e-08
# Epoch 309/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 3.2680e-08
# Epoch 310/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 2.7361e-08
# Epoch 311/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 2.8569e-08
# Epoch 312/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 3.0578e-08
# Epoch 313/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 2.8907e-08
# Epoch 314/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 2.8724e-08
# Epoch 315/2000
# 3/3 [==============================] - 1s 239ms/step - loss: 2.7959e-08
# Epoch 316/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 3.0625e-08
# Epoch 317/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.0693e-08
# Epoch 318/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 3.1764e-08
# Epoch 319/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 3.6830e-08
# Epoch 320/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 3.1205e-08
# Epoch 321/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 3.6474e-08
# Epoch 322/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 3.3012e-08
# Epoch 323/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 3.1576e-08
# Epoch 324/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 3.2236e-08
# Epoch 325/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 2.7428e-08
# Epoch 326/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 2.9929e-08
# Epoch 327/2000
# 3/3 [==============================] - 0s 183ms/step - loss: 3.4178e-08
# Epoch 328/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 3.3362e-08
# Epoch 329/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 3.6146e-08
# Epoch 330/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 3.9994e-08
# Epoch 331/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 3.9151e-08
# Epoch 332/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 2.6024e-08
# Epoch 333/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 2.9383e-08
# Epoch 334/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 2.8634e-08
# Epoch 335/2000
# 3/3 [==============================] - 1s 158ms/step - loss: 3.1770e-08
# Epoch 336/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 3.9053e-08
# Epoch 337/2000
# 3/3 [==============================] - 1s 169ms/step - loss: 2.9694e-08
# Epoch 338/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 3.6000e-08
# Epoch 339/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 3.1017e-08
# Epoch 340/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 5.0220e-08
# Epoch 341/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.4450e-08
# Epoch 342/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 3.2611e-08
# Epoch 343/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 3.2490e-08
# Epoch 344/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 5.3280e-08
# Epoch 345/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 4.6981e-08
# Epoch 346/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.2701e-08
# Epoch 347/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.7771e-08
# Epoch 348/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 3.0781e-08
# Epoch 349/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 4.0188e-08
# Epoch 350/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 3.0156e-08
# Epoch 351/2000
# 3/3 [==============================] - 1s 361ms/step - loss: 3.2964e-08
# Epoch 352/2000
# 3/3 [==============================] - 1s 457ms/step - loss: 3.3198e-08
# Epoch 353/2000
# 3/3 [==============================] - 1s 205ms/step - loss: 3.6470e-08
# Epoch 354/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 2.8494e-08
# Epoch 355/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 2.7752e-08
# Epoch 356/2000
# 3/3 [==============================] - 1s 208ms/step - loss: 3.5732e-08
# Epoch 357/2000
# 3/3 [==============================] - 1s 158ms/step - loss: 3.4827e-08
# Epoch 358/2000
# 3/3 [==============================] - 0s 170ms/step - loss: 3.4964e-08
# Epoch 359/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 3.1392e-08
# Epoch 360/2000
# 3/3 [==============================] - 1s 172ms/step - loss: 3.0324e-08
# Epoch 361/2000
# 3/3 [==============================] - 1s 532ms/step - loss: 4.4142e-08
# Epoch 362/2000
# 3/3 [==============================] - 1s 134ms/step - loss: 3.7458e-08

# %%
def predictValue(model, X_):
    X = X_.reshape((1, nSeq, nRow, nCol, nChannel))
    yhat_ = model.predict(X, verbose=0)
    yhat = yhat_.flatten()
    return yhat

# %%
X_ = data[1:1+nSeq, :]
predictValue(ConvLSTM, X_)
# Out:
# array([-2.8437446e-04, -2.8515002e-04, -6.2476145e-05,  2.3775734e-04,
#         5.0187670e-04,  1.4636917e-03,  4.2243805e-03,  1.1618746e-02,
#         2.9847274e-02,  6.8423085e-02,  1.4043911e-01,  2.5556785e-01,
#         4.0927154e-01,  5.7467848e-01,  7.1284211e-01,  7.9038310e-01,
#         7.9020888e-01,  7.1270460e-01,  5.7463932e-01,  4.0903491e-01,
#         2.5565407e-01,  1.4061025e-01,  6.8278670e-02,  2.9576054e-02,
#         1.1712754e-02,  4.1453876e-03,  1.3262434e-03,  4.2070495e-04,
#        -6.8355119e-05, -5.4755714e-05, -8.6951023e-04, -1.7730566e-04],
#       dtype=float32)

# %%
plt.plot(predictValue(ConvLSTM, X_))
predictValue(ConvLSTM, X_)
# Out:
# array([-2.8437446e-04, -2.8515002e-04, -6.2476145e-05,  2.3775734e-04,
#         5.0187670e-04,  1.4636917e-03,  4.2243805e-03,  1.1618746e-02,
#         2.9847274e-02,  6.8423085e-02,  1.4043911e-01,  2.5556785e-01,
#         4.0927154e-01,  5.7467848e-01,  7.1284211e-01,  7.9038310e-01,
#         7.9020888e-01,  7.1270460e-01,  5.7463932e-01,  4.0903491e-01,
#         2.5565407e-01,  1.4061025e-01,  6.8278670e-02,  2.9576054e-02,
#         1.1712754e-02,  4.1453876e-03,  1.3262434e-03,  4.2070495e-04,
#        -6.8355119e-05, -5.4755714e-05, -8.6951023e-04, -1.7730566e-04],
#       dtype=float32)

# %%
def calculateForecast(model, X_, nForecast):
    yA = list()
    
    for i in range(nSeq):
        yA.append(X_[i,:])
    
    for i in range(nForecast):
        XA = np.array(yA[-nSeq:])
        X = XA.reshape((1, nSeq, nRow, nCol, nChannel))
        yhat = predictValue(model, X)
        yA.append(yhat)

    return np.array(yA[nSeq:])

# %%
tFinal = data.shape[0]
nForecast = tFinal - nSeq
yPred = calculateForecast(ConvLSTM, data[:nSeq,:], nForecast)

# %%
yPred.shape
# Out:
# (91, 32)

# %%
xp = np.arange(0,L,dx)
for t in range(0, tFinal, 30):
    fig, ax = plt.subplots()
    yPFC = y[t,:]
    yML = yPred[t,:]
    ax.plot(xp, yPFC, '*--')
    ax.plot(xp, yML,'s')
    ax.set_title(f'Time={t+nSeq}')
    ax.set_ylim([0,1])

# %%
xp = np.arange(nSeq,tFinal+1)
errL2 = list()
for t in range(y.shape[0]):
    yPFC = y[t,:]
    yML = yPred[t,:]
    errL2.append(np.linalg.norm(yPFC-yML))
errL2 = np.array(errL2)

fig, ax = plt.subplots()
ax.plot(xp, errL2,'--*')
ax.set_title(r'L2-norm of Error')
ax.set_xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')
