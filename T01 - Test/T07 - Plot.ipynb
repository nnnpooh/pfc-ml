# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_theme()

# %%
x = np.arange(0, 10, 0.1)
y = np.sin(x)


fig, ax = plt.subplots()
plt.plot(x, y)

# ax.set_xlabel('$\phi_{ave}$-Prediction Error')

ax.set_xlabel('Fraction of Violation ($E_{law}$)')
# Out:
# Text(0.5, 0, 'Fraction of Violation ($E_{law}$)')
